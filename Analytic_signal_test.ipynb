# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import hilbert, chirp

# %%
t = np.arange(start=0,stop=0.5,step=0.001)
x = np.sin(2*np.pi*10*t)
x_hilbert = np.imag(hilbert(x))

# %%
plt.plot(t,x)
plt.plot(t,x_hilbert)
